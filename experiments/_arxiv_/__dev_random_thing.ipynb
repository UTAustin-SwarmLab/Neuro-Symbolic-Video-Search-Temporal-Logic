# %%
from pathlib import Path

# %%
benchmark_frame_video_root_dir = Path(
    "/opt/Neuro-Symbolic-Video-Frame-Search/artifacts/_validated_benchmark_video"
)

# %%
data
# Out:
# {'"toilet" U "oven"_25_0': {'benchmark_video': BenchmarkLTLFrame(ground_truth=True, ltl_formula='"vase" U "boat"', proposition=['vase', 'boat'], number_of_frame=50, frames_of_interest=[[8, 9], [13, 17], [24, 28], [32, 35], [41, 47]], labels_of_frames=['clock', 'person', 'giraffe', 'truck', 'car', 'person', 'motorcycle', 'tv', 'vase', 'boat', 'elephant', 'bed', 'person', 'vase', 'bench', 'sheep', 'scissors', 'boat', 'person', 'train', 'chair', 'clock', 'apple', 'motorcycle', 'vase', 'giraffe', 'clock', 'person', 'boat', 'dog', 'bird', 'bench', 'vase', 'surfboard', 'person', 'boat', 'person', 'person', 'person', 'bench', 'person', 'vase', 'dog', 'person', 'person', 'person', 'dog', 'boat', 'cat', 'clock'], images_of_frames=[array([[[110, 154, 203],
#           [110, 154, 203],
#           [110, 154, 203],
#           ...,
#           [113, 155, 205],
#           [113, 155, 205],
#           [113, 155, 205]],
#
#          [[110, 154, 203],
#           [110, 154, 203],
#           [110, 154, 203],
#           ...,
#           [113, 155, 205],
#           [113, 155, 205],
#           [113, 155, 205]],
#
#          [[110, 154, 203],
#           [110, 154, 203],
#           [110, 154, 203],
#           ...,
#           [113, 155, 205],
#           [113, 155, 205],
#           [113, 155, 205]],
#
#          ...,
#
#          [[213, 197, 182],
#           [208, 197, 167],
#           [208, 198, 171],
#           ...,
#           [241, 241, 241],
#           [242, 242, 242],
#           [241, 239, 242]],
#
#          [[210, 203, 184],
#           [214, 210, 172],
#           [212, 205, 176],
#           ...,
#           [237, 237, 225],
#           [242, 242, 230],
#           [245, 241, 232]],
#
#          [[207, 207, 181],
#           [206, 208, 161],
#           [210, 207, 172],
#           ...,
#           [166, 165, 135],
#           [168, 167, 137],
#           [170, 171, 140]]], dtype=uint8), array([[[136, 147, 139],
#           [128, 142, 125],
#           [142, 163, 130],
#           ...,
#           [ 19,  21,  10],
#           [ 84,  84,  86],
#           [240, 240, 238]],
#
#          [[136, 147, 139],
#           [156, 170, 155],
#           [102, 121,  91],
#           ...,
#           [177, 174, 195],
#           [235, 238, 217],
#           [ 27,  31,   8]],
#
#          [[ 94, 105,  97],
#           [149, 163, 148],
#           [114, 129, 106],
#           ...,
#           [166, 172, 134],
#           [  1,   0,  10],
#           [126, 123, 144]],
#
#          ...,
#
#          [[ 46,  47,  39],
#           [ 38,  44,  34],
#           [ 33,  43,  34],
#           ...,
#           [  0,   0,   0],
#           [  0,   0,   0],
#           [  0,   0,   0]],
#
#          [[ 42,  43,  37],
#           [ 37,  42,  35],
#           [ 29,  39,  30],
#           ...,
#           [  1,   1,   1],
#           [  1,   1,   1],
#           [  1,   1,   1]],
#
#          [[ 41,  42,  37],
#           [ 44,  49,  43],
#           [ 33,  43,  35],
#           ...,
#           [  2,   2,   2],
#           [  2,   2,   2],
#           [  2,   2,   2]]], dtype=uint8), array([[[ 27,  34,  42],
#           [ 26,  36,  38],
#           [ 29,  38,  37],
#           ...,
#           [ 81,  88,  11],
#           [ 80,  86,  12],
#           [ 71,  71,  19]],
#
#          [[ 26,  33,  41],
#           [ 23,  31,  34],
#           [ 34,  42,  44],
#           ...,
#           [ 86,  94,  11],
#           [ 75,  80,  13],
#           [ 58,  58,   8]],
#
#          [[ 33,  40,  46],
#           [ 25,  33,  36],
#           [ 30,  38,  40],
#           ...,
#           [ 82,  90,   5],
#           [ 64,  68,   7],
#           [ 44,  46,   0]],
#
#          ...,
#
#          [[ 90,  74,  85],
#           [135, 106, 102],
#           [186, 137, 120],
#           ...,
#           [ 50,  54,  92],
#           [ 32,  27,  49],
#           [ 52,  32,  43]],
#
#          [[170, 132, 111],
#           [200, 154, 121],
#           [186, 133,  89],
#           ...,
#           [ 97, 114, 158],
#           [ 69,  76, 102],
#           [ 24,  12,  26]],
#
#          [[222, 166, 115],
#           [227, 164, 113],
#           [241, 182, 138],
#           ...,
#           [ 71,  89, 139],
#           [ 73,  84, 114],
#           [ 81,  72,  89]]], dtype=uint8), array([[[129, 172, 250],
#           [129, 166, 246],
#           [138, 171, 252],
#           ...,
#           [140, 155, 222],
#           [158, 189, 243],
#           [129, 174, 215]],
#
#          [[151, 179, 255],
#           [132, 171, 250],
#           [126, 174, 250],
#           ...,
#           [155, 202, 244],
#           [158, 221, 254],
#           [136, 209, 241]],
#
#          [[138, 177, 255],
#           [130, 167, 247],
#           [141, 176, 255],
#           ...,
#           [160, 185, 249],
#           [143, 170, 237],
#           [168, 199, 255]],
#
#          ...,
#
#          [[ 98,  96, 110],
#           [ 85,  84,  98],
#           [102, 100, 113],
#           ...,
#           [ 49,  19,  57],
#           [ 49,  19,  57],
#           [ 52,  22,  58]],
#
#          [[105, 101, 115],
#           [ 90,  88, 101],
#           [103, 103, 115],
#           ...,
#           [ 46,  18,  41],
#           [ 46,  21,  42],
#           [ 48,  25,  43]],
#
#          [[109, 101, 116],
#           [103,  99, 113],
#           [ 98,  98, 110],
#           ...,
#           [ 45,   7,  44],
#           [ 49,  14,  46],
#           [ 55,  21,  46]]], dtype=uint8), array([[[200, 200, 166],
#           [204, 204, 170],
#           [204, 205, 173],
#           ...,
#           [206, 220, 246],
#           [207, 219, 245],
#           [208, 217, 246]],
#
#          [[203, 200, 167],
#           [206, 206, 172],
#           [205, 205, 171],
#           ...,
#           [204, 218, 245],
#           [208, 219, 249],
#           [209, 220, 252]],
#
#          [[203, 199, 161],
#           [206, 202, 165],
#           [211, 206, 174],
#           ...,
#           [205, 219, 245],
#           [208, 219, 249],
#           [210, 221, 253]],
#
#          ...,
#
#          [[175, 190, 149],
#           [179, 191, 153],
#           [185, 192, 158],
#           ...,
#           [175, 172, 165],
#           [181, 178, 173],
#           [157, 153, 152]],
#
#          [[174, 189, 148],
#           [178, 190, 152],
#           [183, 193, 159],
#           ...,
#           [159, 160, 155],
#           [151, 151, 149],
#           [156, 156, 156]],
#
#          [[175, 189, 153],
#           [179, 191, 155],
#           [183, 193, 159],
#           ...,
#           [163, 160, 155],
#           [163, 160, 155],
#           [159, 158, 153]]], dtype=uint8), array([[[100, 143, 188],
#           [101, 144, 189],
#           [101, 144, 189],
#           ...,
#           [109, 153, 202],
#           [109, 153, 202],
#           [109, 153, 202]],
#
#          [[101, 143, 191],
#           [101, 143, 191],
#           [101, 143, 191],
#           ...,
#           [111, 155, 204],
#           [110, 154, 203],
#           [110, 154, 203]],
#
#          [[102, 144, 192],
#           [102, 144, 192],
#           [102, 144, 192],
#           ...,
#           [112, 156, 203],
#           [111, 155, 202],
#           [110, 154, 201]],
#
#          ...,
#
#          [[ 33,  33,  31],
#           [ 33,  33,  31],
#           [ 34,  35,  30],
#           ...,
#           [ 12,  11,   9],
#           [ 23,  23,  23],
#           [ 30,  30,  32]],
#
#          [[ 34,  34,  32],
#           [ 36,  36,  34],
#           [ 37,  38,  33],
#           ...,
#           [  4,   3,   1],
#           [ 11,   9,  10],
#           [ 19,  17,  22]],
#
#          [[ 34,  34,  32],
#           [ 32,  32,  30],
#           [ 35,  35,  33],
#           ...,
#           [ 12,  11,   9],
#           [  7,   5,   6],
#           [  8,   6,   9]]], dtype=uint8), array([[[255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255],
#           ...,
#           [255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255]],
#
#          [[255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255],
#           ...,
#           [255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255]],
#
#          [[255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255],
#           ...,
#           [255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255]],
#
#          ...,
#
#          [[255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255],
#           ...,
#           [255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255]],
#
#          [[255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255],
#           ...,
#           [255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255]],
#
#          [[255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255],
#           ...,
#           [255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255]]], dtype=uint8), array([[[138, 136, 149],
#           [134, 134, 146],
#           [138, 138, 150],
#           ...,
#           [179, 174, 168],
#           [181, 178, 171],
#           [178, 175, 168]],
#
#          [[142, 142, 154],
#           [135, 135, 147],
#           [136, 136, 148],
#           ...,
#           [184, 180, 171],
#           [179, 175, 164],
#           [177, 173, 162]],
#
#          [[130, 130, 142],
#           [132, 134, 146],
#           [129, 131, 143],
#           ...,
#           [176, 168, 165],
#           [170, 163, 157],
#           [182, 175, 167]],
#
#          ...,
#
#          [[199, 182, 175],
#           [183, 163, 156],
#           [217, 194, 180],
#           ...,
#           [166, 156, 146],
#           [169, 159, 149],
#           [180, 163, 155]],
#
#          [[219, 186, 177],
#           [187, 160, 149],
#           [214, 195, 188],
#           ...,
#           [170, 163, 155],
#           [174, 156, 152],
#           [175, 151, 147]],
#
#          [[200, 190, 180],
#           [203, 189, 178],
#           [201, 183, 171],
#           ...,
#           [163, 153, 151],
#           [174, 154, 155],
#           [171, 151, 150]]], dtype=uint8), array([[[ 32,   0,   6],
#           [ 31,  18,  27],
#           [121, 121, 113],
#           ...,
#           [204, 194, 193],
#           [184, 172, 172],
#           [177, 166, 164]],
#
#          [[ 40,  13,  28],
#           [  1,   5,   4],
#           [ 49,  31,  47],
#           ...,
#           [195, 178, 170],
#           [177, 159, 149],
#           [165, 146, 139]],
#
#          [[ 32,   8,  21],
#           [ 11,   1,   0],
#           [ 45,  27,  27],
#           ...,
#           [186, 164, 151],
#           [187, 168, 154],
#           [167, 150, 134]],
#
#          ...,
#
#          [[ 73,  77,  80],
#           [ 66,  66,  66],
#           [ 73,  64,  57],
#           ...,
#           [ 56,  46,  45],
#           [ 66,  52,  52],
#           [ 78,  58,  57]],
#
#          [[ 60,  55,  51],
#           [ 74,  62,  62],
#           [ 83,  60,  68],
#           ...,
#           [ 56,  48,  46],
#           [ 54,  45,  46],
#           [ 73,  64,  65]],
#
#          [[ 78,  65,  57],
#           [ 67,  59,  56],
#           [ 65,  56,  59],
#           ...,
#           [ 68,  54,  53],
#           [ 60,  47,  38],
#           [ 63,  46,  52]]], dtype=uint8), array([[[144, 163, 232],
#           [148, 159, 239],
#           [150, 162, 244],
#           ...,
#           [124, 146, 206],
#           [120, 144, 208],
#           [129, 139, 210]],
#
#          [[146, 165, 241],
#           [146, 163, 233],
#           [144, 163, 231],
#           ...,
#           [124, 146, 204],
#           [115, 147, 204],
#           [121, 145, 207]],
#
#          [[132, 165, 242],
#           [145, 165, 236],
#           [151, 160, 229],
#           ...,
#           [123, 148, 204],
#           [117, 150, 203],
#           [119, 148, 204]],
#
#          ...,
#
#          [[185, 159, 186],
#           [193, 167, 178],
#           [204, 173, 181],
#           ...,
#           [180, 153, 142],
#           [186, 156, 146],
#           [184, 157, 148]],
#
#          [[182, 170, 174],
#           [190, 174, 174],
#           [200, 173, 188],
#           ...,
#           [180, 156, 156],
#           [185, 156, 152],
#           [178, 151, 144]],
#
#          [[196, 184, 196],
#           [190, 176, 175],
#           [193, 167, 178],
#           ...,
#           [179, 159, 152],
#           [180, 156, 144],
#           [179, 157, 144]]], dtype=uint8), array([[[238, 228, 239],
#           [236, 226, 237],
#           [235, 225, 236],
#           ...,
#           [243, 236, 243],
#           [244, 237, 244],
#           [244, 237, 244]],
#
#          [[235, 227, 238],
#           [235, 229, 239],
#           [235, 229, 239],
#           ...,
#           [243, 236, 243],
#           [243, 236, 243],
#           [243, 236, 243]],
#
#          [[233, 230, 239],
#           [233, 230, 239],
#           [232, 229, 238],
#           ...,
#           [241, 236, 242],
#           [242, 237, 243],
#           [242, 237, 243]],
#
#          ...,
#
#          [[143, 106,  87],
#           [152, 115,  97],
#           [143, 108,  89],
#           ...,
#           [154, 119, 100],
#           [153, 120, 101],
#           [158, 125, 106]],
#
#          [[148, 115,  96],
#           [148, 115,  96],
#           [156, 124, 103],
#           ...,
#           [151, 118, 101],
#           [146, 115,  95],
#           [153, 125, 103]],
#
#          [[150, 119,  99],
#           [162, 131, 110],
#           [133, 103,  77],
#           ...,
#           [139, 110,  92],
#           [149, 122, 101],
#           [148, 124, 100]]], dtype=uint8), array([[[108, 102,  78],
#           [111, 105,  81],
#           [112, 106,  82],
#           ...,
#           [175, 174, 143],
#           [174, 173, 142],
#           [174, 173, 142]],
#
#          [[116, 111,  91],
#           [117, 112,  92],
#           [117, 112,  92],
#           ...,
#           [175, 174, 143],
#           [174, 173, 142],
#           [173, 172, 141]],
#
#          [[117, 114,  97],
#           [118, 115,  98],
#           [117, 114,  97],
#           ...,
#           [175, 174, 144],
#           [175, 174, 144],
#           [174, 173, 143]],
#
#          ...,
#
#          [[ 93, 102,  59],
#           [ 90,  99,  56],
#           [ 95, 102,  60],
#           ...,
#           [ 83,  89,  55],
#           [ 84,  90,  56],
#           [ 84,  90,  56]],
#
#          [[ 91, 103,  57],
#           [ 89,  98,  53],
#           [ 93, 100,  58],
#           ...,
#           [ 82,  88,  54],
#           [ 82,  88,  54],
#           [ 82,  88,  54]],
#
#          [[ 89, 101,  53],
#           [ 87,  96,  51],
#           [ 91,  98,  54],
#           ...,
#           [ 82,  88,  54],
#           [ 81,  87,  53],
#           [ 80,  86,  52]]], dtype=uint8), array([[[200, 230, 255],
#           [200, 230, 254],
#           [201, 231, 255],
#           ...,
#           [ 52,  60,  73],
#           [ 53,  59,  73],
#           [ 53,  59,  73]],
#
#          [[200, 230, 254],
#           [201, 231, 255],
#           [201, 231, 255],
#           ...,
#           [ 50,  58,  71],
#           [ 51,  57,  71],
#           [ 50,  56,  70]],
#
#          [[200, 230, 254],
#           [201, 231, 255],
#           [202, 233, 254],
#           ...,
#           [ 51,  57,  71],
#           [ 50,  56,  70],
#           [ 50,  56,  70]],
#
#          ...,
#
#          [[ 51,  52,  56],
#           [ 39,  40,  44],
#           [ 30,  29,  34],
#           ...,
#           [190, 191, 183],
#           [163, 161, 149],
#           [149, 145, 133]],
#
#          [[ 43,  44,  48],
#           [ 34,  35,  39],
#           [ 28,  27,  32],
#           ...,
#           [168, 169, 161],
#           [146, 144, 132],
#           [149, 145, 133]],
#
#          [[ 26,  27,  32],
#           [ 24,  25,  30],
#           [ 24,  25,  29],
#           ...,
#           [160, 161, 153],
#           [141, 139, 127],
#           [153, 149, 137]]], dtype=uint8), array([[[101,  88,  71],
#           [102,  89,  72],
#           [101,  88,  71],
#           ...,
#           [132,  98,  26],
#           [129,  95,  23],
#           [127,  93,  21]],
#
#          [[102,  88,  75],
#           [102,  88,  75],
#           [102,  88,  75],
#           ...,
#           [130,  96,  24],
#           [129,  95,  23],
#           [127,  93,  21]],
#
#          [[102,  88,  79],
#           [102,  88,  77],
#           [103,  89,  78],
#           ...,
#           [130,  96,  24],
#           [128,  94,  22],
#           [125,  91,  19]],
#
#          ...,
#
#          [[ 82,  75,  69],
#           [ 87,  80,  72],
#           [ 88,  81,  73],
#           ...,
#           [252, 252, 252],
#           [142, 142, 142],
#           [  0,   0,   0]],
#
#          [[ 84,  77,  71],
#           [ 85,  78,  72],
#           [ 87,  80,  74],
#           ...,
#           [165, 165, 165],
#           [ 78,  78,  78],
#           [  1,   1,   1]],
#
#          [[ 84,  77,  71],
#           [ 90,  83,  77],
#           [ 86,  79,  73],
#           ...,
#           [  0,   0,   0],
#           [  1,   1,   1],
#           [  7,   7,   7]]], dtype=uint8), array([[[148, 165, 183],
#           [141, 163, 161],
#           [140, 163, 155],
#           ...,
#           [ 44,  52,  28],
#           [ 41,  41,  31],
#           [ 47,  40,  22]],
#
#          [[138, 156, 166],
#           [144, 166, 163],
#           [146, 167, 168],
#           ...,
#           [ 26,  35,  16],
#           [ 37,  37,  25],
#           [ 50,  44,  18]],
#
#          [[136, 156, 157],
#           [140, 163, 157],
#           [141, 161, 170],
#           ...,
#           [ 24,  36,  12],
#           [ 36,  36,  26],
#           [ 44,  37,  19]],
#
#          ...,
#
#          [[167, 160, 154],
#           [152, 153, 122],
#           [133, 141,  92],
#           ...,
#           [126, 144,  96],
#           [ 94, 107,  61],
#           [110, 122,  74]],
#
#          [[156, 151, 148],
#           [137, 139, 115],
#           [125, 132,  91],
#           ...,
#           [108, 125,  73],
#           [101, 115,  64],
#           [112, 124,  74]],
#
#          [[149, 145, 144],
#           [138, 140, 119],
#           [114, 120,  86],
#           ...,
#           [117, 131,  78],
#           [115, 128,  75],
#           [119, 131,  81]]], dtype=uint8), array([[[ 89, 137,  77],
#           [ 97, 145,  85],
#           [ 90, 138,  78],
#           ...,
#           [130, 169, 166],
#           [131, 170, 165],
#           [129, 169, 161]],
#
#          [[ 83, 126,  80],
#           [ 93, 136,  90],
#           [ 89, 132,  86],
#           ...,
#           [139, 175, 173],
#           [140, 176, 172],
#           [139, 175, 171]],
#
#          [[ 83, 117,  92],
#           [ 95, 129, 102],
#           [ 94, 128, 101],
#           ...,
#           [144, 175, 177],
#           [145, 177, 176],
#           [144, 176, 173]],
#
#          ...,
#
#          [[129, 126, 157],
#           [140, 137, 168],
#           [143, 142, 173],
#           ...,
#           [112, 124, 122],
#           [117, 129, 127],
#           [121, 133, 131]],
#
#          [[143, 143, 171],
#           [146, 146, 174],
#           [146, 145, 176],
#           ...,
#           [123, 135, 131],
#           [124, 136, 132],
#           [125, 137, 133]],
#
#          [[151, 151, 177],
#           [148, 148, 174],
#           [147, 147, 175],
#           ...,
#           [113, 125, 121],
#           [109, 121, 117],
#           [108, 120, 116]]], dtype=uint8), array([[[246, 249, 255],
#           [236, 239, 248],
#           [239, 241, 254],
#           ...,
#           [255, 224, 195],
#           [250, 221, 191],
#           [255, 231, 202]],
#
#          [[234, 237, 246],
#           [219, 221, 233],
#           [227, 229, 244],
#           ...,
#           [251, 216, 188],
#           [245, 209, 183],
#           [254, 217, 191]],
#
#          [[240, 243, 252],
#           [219, 221, 234],
#           [230, 232, 247],
#           ...,
#           [251, 214, 188],
#           [246, 208, 185],
#           [253, 217, 193]],
#
#          ...,
#
#          [[235, 178, 158],
#           [229, 172, 152],
#           [225, 169, 146],
#           ...,
#           [230, 164, 130],
#           [221, 155, 121],
#           [211, 145, 111]],
#
#          [[238, 181, 164],
#           [225, 168, 151],
#           [227, 170, 151],
#           ...,
#           [219, 153, 119],
#           [205, 139, 105],
#           [222, 153, 120]],
#
#          [[251, 195, 180],
#           [232, 176, 159],
#           [240, 183, 166],
#           ...,
#           [229, 160, 127],
#           [228, 159, 126],
#           [238, 169, 136]]], dtype=uint8), array([[[ 85, 131, 193],
#           [ 86, 132, 194],
#           [ 86, 132, 192],
#           ...,
#           [ 74, 115, 181],
#           [ 74, 115, 179],
#           [ 75, 116, 180]],
#
#          [[ 87, 135, 199],
#           [ 87, 135, 199],
#           [ 89, 134, 199],
#           ...,
#           [ 77, 118, 182],
#           [ 78, 119, 181],
#           [ 78, 120, 180]],
#
#          [[ 86, 135, 202],
#           [ 87, 134, 202],
#           [ 87, 135, 201],
#           ...,
#           [ 78, 120, 180],
#           [ 78, 120, 180],
#           [ 78, 120, 178]],
#
#          ...,
#
#          [[164, 170, 170],
#           [171, 177, 177],
#           [178, 182, 183],
#           ...,
#           [ 90, 108, 110],
#           [ 86, 101, 104],
#           [ 72,  87,  94]],
#
#          [[170, 179, 178],
#           [174, 183, 182],
#           [179, 185, 185],
#           ...,
#           [ 73,  91,  93],
#           [ 82, 100, 102],
#           [101, 116, 121]],
#
#          [[175, 185, 184],
#           [176, 185, 184],
#           [176, 182, 182],
#           ...,
#           [ 58,  79,  82],
#           [ 93, 112, 116],
#           [104, 121, 128]]], dtype=uint8), array([[[  9,  29,  79],
#           [ 11,  29,  79],
#           [ 12,  28,  79],
#           ...,
#           [ 17,  39,  89],
#           [ 13,  39,  88],
#           [ 11,  39,  87]],
#
#          [[  8,  28,  78],
#           [ 10,  28,  78],
#           [ 10,  28,  78],
#           ...,
#           [ 17,  39,  89],
#           [ 15,  38,  88],
#           [ 15,  38,  88]],
#
#          [[  8,  28,  78],
#           [  8,  28,  78],
#           [  8,  28,  78],
#           ...,
#           [ 16,  38,  88],
#           [ 18,  38,  89],
#           [ 20,  37,  89]],
#
#          ...,
#
#          [[114, 118, 153],
#           [107, 112, 142],
#           [116, 120, 149],
#           ...,
#           [ 10,  16,  52],
#           [ 63,  68, 106],
#           [ 78,  84, 118]],
#
#          [[120, 124, 159],
#           [115, 120, 150],
#           [128, 132, 159],
#           ...,
#           [124, 127, 158],
#           [ 49,  52,  83],
#           [ 39,  42,  75]],
#
#          [[127, 132, 162],
#           [130, 134, 163],
#           [137, 139, 164],
#           ...,
#           [134, 132, 156],
#           [163, 163, 187],
#           [120, 119, 150]]], dtype=uint8), array([[[253, 254, 255],
#           [254, 255, 255],
#           [254, 254, 254],
#           ...,
#           [255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255]],
#
#          [[254, 255, 255],
#           [254, 255, 255],
#           [255, 255, 255],
#           ...,
#           [255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255]],
#
#          [[255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 253],
#           ...,
#           [255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255]],
#
#          ...,
#
#          [[255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255],
#           ...,
#           [255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255]],
#
#          [[255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255],
#           ...,
#           [255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255]],
#
#          [[255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255],
#           ...,
#           [255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255]]], dtype=uint8), array([[[178, 188, 179],
#           [177, 187, 179],
#           [183, 188, 184],
#           ...,
#           [173, 169, 183],
#           [178, 174, 188],
#           [181, 177, 191]],
#
#          [[172, 178, 166],
#           [175, 181, 171],
#           [177, 180, 173],
#           ...,
#           [178, 176, 177],
#           [176, 175, 173],
#           [178, 179, 174]],
#
#          [[191, 192, 184],
#           [185, 186, 180],
#           [191, 192, 186],
#           ...,
#           [167, 167, 167],
#           [176, 176, 176],
#           [176, 176, 174]],
#
#          ...,
#
#          [[123, 120, 127],
#           [121, 120, 126],
#           [120, 119, 124],
#           ...,
#           [126, 124, 129],
#           [128, 126, 131],
#           [124, 121, 128]],
#
#          [[119, 115, 129],
#           [115, 112, 123],
#           [121, 118, 127],
#           ...,
#           [125, 123, 128],
#           [125, 122, 129],
#           [123, 120, 131]],
#
#          [[124, 119, 126],
#           [123, 118, 125],
#           [123, 118, 124],
#           ...,
#           [126, 123, 130],
#           [121, 118, 125],
#           [124, 121, 128]]], dtype=uint8), array([[[ 30,  35,  39],
#           [ 34,  44,  80],
#           [ 29,  16,  72],
#           ...,
#           [ 19,  18,  16],
#           [ 22,  22,  20],
#           [ 27,  28,  23]],
#
#          [[ 28,  38,  40],
#           [ 49,  69,  96],
#           [122, 124, 162],
#           ...,
#           [ 22,  23,  17],
#           [ 25,  28,  19],
#           [ 38,  41,  32]],
#
#          [[ 31,  32,  37],
#           [ 10,  29,  46],
#           [ 98, 107, 124],
#           ...,
#           [ 25,  29,  15],
#           [ 19,  26,  10],
#           [ 27,  36,  19]],
#
#          ...,
#
#          [[ 12,  13,   8],
#           [ 14,  15,  10],
#           [ 23,  24,  18],
#           ...,
#           [ 57,  63,  63],
#           [ 59,  60,  62],
#           [ 59,  59,  61]],
#
#          [[ 11,  12,   7],
#           [  6,   7,   2],
#           [ 14,  15,   9],
#           ...,
#           [ 81,  87,  85],
#           [ 85,  87,  86],
#           [ 87,  87,  87]],
#
#          [[ 16,  17,  12],
#           [ 11,  12,   7],
#           [ 17,  18,  12],
#           ...,
#           [ 81,  87,  83],
#           [ 83,  87,  86],
#           [ 87,  87,  87]]], dtype=uint8), array([[[ 29,  47,  31],
#           [ 33,  50,  34],
#           [ 25,  39,  24],
#           ...,
#           [221, 201, 166],
#           [220, 200, 165],
#           [222, 202, 167]],
#
#          [[ 26,  44,  28],
#           [ 30,  44,  29],
#           [ 40,  52,  38],
#           ...,
#           [219, 199, 164],
#           [219, 199, 164],
#           [219, 199, 164]],
#
#          [[ 25,  42,  24],
#           [ 27,  41,  24],
#           [ 40,  51,  37],
#           ...,
#           [219, 199, 164],
#           [218, 198, 163],
#           [218, 198, 163]],
#
#          ...,
#
#          [[ 77,  57,   4],
#           [ 74,  54,   3],
#           [ 77,  56,   9],
#           ...,
#           [ 60,  36,   8],
#           [ 63,  39,  13],
#           [ 59,  35,   9]],
#
#          [[ 79,  59,   6],
#           [ 75,  55,   4],
#           [ 73,  52,   5],
#           ...,
#           [ 58,  34,   8],
#           [ 60,  36,  12],
#           [ 59,  35,  11]],
#
#          [[ 77,  58,   2],
#           [ 77,  57,   6],
#           [ 71,  51,   1],
#           ...,
#           [ 52,  30,   6],
#           [ 53,  31,   8],
#           [ 55,  33,  12]]], dtype=uint8), array([[[110, 139, 171],
#           [101, 134, 167],
#           [113, 141, 178],
#           ...,
#           [121, 140, 155],
#           [126, 143, 161],
#           [128, 140, 162]],
#
#          [[109, 138, 170],
#           [ 89, 120, 149],
#           [101, 124, 155],
#           ...,
#           [124, 143, 158],
#           [126, 143, 161],
#           [126, 141, 162]],
#
#          [[ 98, 132, 160],
#           [ 74, 105, 126],
#           [ 85, 106, 125],
#           ...,
#           [125, 144, 159],
#           [126, 143, 161],
#           [128, 143, 162]],
#
#          ...,
#
#          [[154, 142, 142],
#           [167, 153, 150],
#           [148, 154, 142],
#           ...,
#           [162, 155, 145],
#           [160, 153, 143],
#           [156, 149, 139]],
#
#          [[166, 166, 158],
#           [161, 157, 146],
#           [150, 153, 142],
#           ...,
#           [156, 149, 141],
#           [153, 149, 140],
#           [160, 157, 148]],
#
#          [[152, 148, 139],
#           [169, 163, 151],
#           [146, 143, 134],
#           ...,
#           [165, 161, 152],
#           [168, 161, 155],
#           [161, 154, 148]]], dtype=uint8), array([[[130, 163,  76],
#           [124, 164,  76],
#           [119, 158,  79],
#           ...,
#           [ 75,  78,  49],
#           [ 82,  78,  53],
#           [ 83,  79,  70]],
#
#          [[120, 149,  65],
#           [128, 153,  59],
#           [120, 149,  57],
#           ...,
#           [ 83,  81,  42],
#           [ 86,  84,  46],
#           [ 71,  83,  61]],
#
#          [[113, 146,  57],
#           [118, 143,  49],
#           [118, 146,  46],
#           ...,
#           [ 69,  84,  55],
#           [ 83,  82,  61],
#           [ 90,  78,  54]],
#
#          ...,
#
#          [[138, 140, 126],
#           [141, 145, 120],
#           [139, 141, 119],
#           ...,
#           [ 91, 100,  73],
#           [ 86, 100,  77],
#           [108, 103,  84]],
#
#          [[138, 141, 120],
#           [144, 138, 122],
#           [145, 141, 112],
#           ...,
#           [ 96,  87,  70],
#           [ 87,  89,  65],
#           [ 92,  96,  69]],
#
#          [[143, 136, 117],
#           [142, 136, 120],
#           [139, 139, 101],
#           ...,
#           [ 93,  88,  84],
#           [ 97,  89,  76],
#           [ 86,  89,  70]]], dtype=uint8), array([[[168, 161, 179],
#           [161, 157, 172],
#           [163, 162, 176],
#           ...,
#           [195, 212, 232],
#           [196, 212, 235],
#           [199, 215, 238]],
#
#          [[162, 159, 178],
#           [157, 154, 171],
#           [157, 156, 172],
#           ...,
#           [190, 206, 231],
#           [191, 207, 232],
#           [195, 211, 237]],
#
#          [[152, 155, 174],
#           [151, 152, 170],
#           [155, 154, 172],
#           ...,
#           [195, 210, 239],
#           [194, 209, 238],
#           [195, 210, 239]],
#
#          ...,
#
#          [[136, 122,  95],
#           [136, 127,  98],
#           [138, 133, 104],
#           ...,
#           [  2,   2,   2],
#           [  1,   1,   1],
#           [  1,   1,   1]],
#
#          [[137, 123,  94],
#           [133, 127,  95],
#           [136, 131, 102],
#           ...,
#           [  3,   3,   3],
#           [  2,   2,   2],
#           [  1,   1,   1]],
#
#          [[123, 112,  80],
#           [128, 122,  90],
#           [133, 130,  99],
#           ...,
#           [  2,   2,   2],
#           [  1,   1,   1],
#           [  1,   1,   1]]], dtype=uint8), array([[[149, 181, 168],
#           [145, 178, 169],
#           [151, 184, 177],
#           ...,
#           [122, 124, 172],
#           [100, 123, 137],
#           [122, 141, 137]],
#
#          [[142, 177, 171],
#           [143, 179, 179],
#           [149, 180, 183],
#           ...,
#           [151, 152, 196],
#           [ 94, 114, 151],
#           [102, 118, 131]],
#
#          [[170, 196, 187],
#           [166, 198, 193],
#           [165, 195, 193],
#           ...,
#           [167, 167, 205],
#           [113, 133, 170],
#           [107, 122, 143]],
#
#          ...,
#
#          [[ 32,  36,  35],
#           [ 38,  42,  41],
#           [ 32,  36,  35],
#           ...,
#           [ 73,  72,  51],
#           [ 77,  78,  44],
#           [ 72,  71,  53]],
#
#          [[ 37,  43,  41],
#           [ 34,  40,  38],
#           [ 33,  42,  39],
#           ...,
#           [ 63,  62,  34],
#           [ 80,  82,  45],
#           [ 74,  75,  44]],
#
#          [[ 30,  41,  37],
#           [ 24,  35,  31],
#           [ 27,  39,  37],
#           ...,
#           [ 68,  66,  27],
#           [ 77,  75,  52],
#           [ 66,  65,  45]]], dtype=uint8), array([[[ 99, 119, 128],
#           [124, 129, 149],
#           [114, 112, 133],
#           ...,
#           [ 81,  82,  77],
#           [ 83,  84,  78],
#           [ 80,  81,  75]],
#
#          [[ 14,  20,   6],
#           [ 25,  20,  17],
#           [ 22,  16,  16],
#           ...,
#           [ 83,  84,  79],
#           [ 85,  86,  81],
#           [ 84,  85,  79]],
#
#          [[ 18,  21,  12],
#           [ 21,  13,  11],
#           [ 21,  17,  18],
#           ...,
#           [ 80,  81,  76],
#           [ 83,  84,  79],
#           [ 83,  84,  79]],
#
#          ...,
#
#          [[214, 197, 179],
#           [214, 201, 184],
#           [212, 200, 184],
#           ...,
#           [ 23,  22,  27],
#           [251, 237, 192],
#           [216, 198, 162]],
#
#          [[213, 196, 178],
#           [215, 202, 185],
#           [215, 204, 186],
#           ...,
#           [ 10,   4,   8],
#           [249, 223, 188],
#           [225, 194, 173]],
#
#          [[210, 195, 174],
#           [213, 200, 183],
#           [214, 203, 185],
#           ...,
#           [ 10,   0,   3],
#           [134, 100,  72],
#           [ 56,  15,   9]]], dtype=uint8), array([[[200, 203, 194],
#           [200, 203, 194],
#           [200, 203, 194],
#           ...,
#           [211, 222, 218],
#           [211, 222, 218],
#           [211, 222, 218]],
#
#          [[200, 203, 194],
#           [200, 203, 194],
#           [201, 204, 195],
#           ...,
#           [210, 221, 217],
#           [210, 221, 217],
#           [210, 221, 217]],
#
#          [[200, 203, 194],
#           [200, 203, 194],
#           [201, 204, 195],
#           ...,
#           [210, 221, 217],
#           [210, 221, 217],
#           [210, 221, 217]],
#
#          ...,
#
#          [[102,  97,  78],
#           [ 98,  93,  74],
#           [101,  96,  77],
#           ...,
#           [ 99, 100,  84],
#           [ 99, 100,  84],
#           [ 99, 100,  84]],
#
#          [[101,  96,  77],
#           [ 98,  93,  74],
#           [101,  96,  77],
#           ...,
#           [ 99, 100,  84],
#           [ 99, 100,  84],
#           [ 99, 100,  84]],
#
#          [[101,  96,  77],
#           [ 98,  93,  74],
#           [101,  96,  77],
#           ...,
#           [ 99, 100,  84],
#           [ 99, 100,  84],
#           [ 99, 100,  84]]], dtype=uint8), array([[[55, 52, 43],
#           [55, 52, 43],
#           [51, 51, 41],
#           ...,
#           [43, 30, 21],
#           [41, 28, 19],
#           [38, 28, 18]],
#
#          [[51, 52, 47],
#           [54, 53, 49],
#           [59, 51, 48],
#           ...,
#           [40, 30, 20],
#           [39, 29, 19],
#           [39, 29, 19]],
#
#          [[58, 49, 44],
#           [60, 53, 47],
#           [57, 57, 49],
#           ...,
#           [43, 31, 19],
#           [43, 31, 19],
#           [43, 30, 21]],
#
#          ...,
#
#          [[68, 74, 72],
#           [69, 75, 73],
#           [68, 77, 74],
#           ...,
#           [79, 69, 59],
#           [83, 74, 67],
#           [76, 65, 61]],
#
#          [[72, 71, 69],
#           [73, 71, 72],
#           [74, 74, 74],
#           ...,
#           [61, 46, 39],
#           [52, 41, 37],
#           [58, 47, 45]],
#
#          [[66, 73, 66],
#           [68, 74, 70],
#           [67, 76, 71],
#           ...,
#           [40, 38, 26],
#           [32, 33, 25],
#           [37, 34, 29]]], dtype=uint8), array([[[123, 157, 185],
#           [120, 155, 183],
#           [122, 157, 185],
#           ...,
#           [ 41,  69,  91],
#           [ 39,  69,  93],
#           [ 40,  70,  94]],
#
#          [[122, 156, 184],
#           [119, 154, 182],
#           [120, 157, 184],
#           ...,
#           [ 37,  67,  91],
#           [ 37,  67,  91],
#           [ 39,  69,  93]],
#
#          [[121, 156, 186],
#           [119, 156, 183],
#           [120, 157, 184],
#           ...,
#           [ 39,  69,  95],
#           [ 39,  69,  93],
#           [ 41,  71,  95]],
#
#          ...,
#
#          [[ 45,  74,  90],
#           [ 44,  70,  85],
#           [ 45,  73,  85],
#           ...,
#           [ 50,  40,  30],
#           [ 45,  35,  26],
#           [ 45,  36,  27]],
#
#          [[ 43,  72,  86],
#           [ 45,  68,  82],
#           [ 42,  70,  82],
#           ...,
#           [ 57,  44,  35],
#           [ 44,  34,  25],
#           [ 48,  39,  30]],
#
#          [[ 45,  73,  87],
#           [ 47,  70,  84],
#           [ 45,  71,  84],
#           ...,
#           [ 70,  57,  48],
#           [ 57,  47,  38],
#           [ 61,  52,  43]]], dtype=uint8), array([[[240, 247, 240],
#           [245, 247, 244],
#           [247, 247, 245],
#           ...,
#           [228, 216, 164],
#           [186, 172, 159],
#           [ 92,  70,  73]],
#
#          [[220, 239, 233],
#           [224, 239, 234],
#           [228, 238, 237],
#           ...,
#           [211, 205, 171],
#           [ 73,  59,  58],
#           [102,  75,  84]],
#
#          [[212, 237, 233],
#           [213, 235, 232],
#           [215, 234, 232],
#           ...,
#           [127, 117, 108],
#           [ 72,  49,  59],
#           [213, 197, 182]],
#
#          ...,
#
#          [[  2,   6,   0],
#           [  4,   0,   4],
#           [ 14,  16,  15],
#           ...,
#           [ 96,  59,  67],
#           [102,  69,  76],
#           [ 95,  60,  56]],
#
#          [[ 31,  18,  25],
#           [ 67,  66,  71],
#           [ 77,  66,  70],
#           ...,
#           [ 94,  64,  64],
#           [114,  72,  74],
#           [ 89,  50,  51]],
#
#          [[ 82,  65,  75],
#           [ 86,  84,  97],
#           [ 75,  61,  76],
#           ...,
#           [109,  53,  54],
#           [114,  66,  66],
#           [115,  70,  73]]], dtype=uint8), array([[[101,  88,  71],
#           [102,  89,  72],
#           [101,  88,  71],
#           ...,
#           [132,  98,  26],
#           [129,  95,  23],
#           [127,  93,  21]],
#
#          [[102,  88,  75],
#           [102,  88,  75],
#           [102,  88,  75],
#           ...,
#           [130,  96,  24],
#           [129,  95,  23],
#           [127,  93,  21]],
#
#          [[102,  88,  79],
#           [102,  88,  77],
#           [103,  89,  78],
#           ...,
#           [130,  96,  24],
#           [128,  94,  22],
#           [125,  91,  19]],
#
#          ...,
#
#          [[ 82,  75,  69],
#           [ 87,  80,  72],
#           [ 88,  81,  73],
#           ...,
#           [252, 252, 252],
#           [142, 142, 142],
#           [  0,   0,   0]],
#
#          [[ 84,  77,  71],
#           [ 85,  78,  72],
#           [ 87,  80,  74],
#           ...,
#           [165, 165, 165],
#           [ 78,  78,  78],
#           [  1,   1,   1]],
#
#          [[ 84,  77,  71],
#           [ 90,  83,  77],
#           [ 86,  79,  73],
#           ...,
#           [  0,   0,   0],
#           [  1,   1,   1],
#           [  7,   7,   7]]], dtype=uint8), array([[[167, 177, 189],
#           [168, 178, 190],
#           [164, 174, 186],
#           ...,
#           [163, 172, 187],
#           [163, 172, 187],
#           [163, 172, 187]],
#
#          [[169, 179, 191],
#           [169, 179, 191],
#           [168, 178, 190],
#           ...,
#           [164, 173, 188],
#           [165, 174, 189],
#           [166, 175, 190]],
#
#          [[167, 177, 189],
#           [166, 176, 188],
#           [169, 179, 191],
#           ...,
#           [163, 172, 187],
#           [164, 173, 188],
#           [165, 174, 189]],
#
#          ...,
#
#          [[184, 183, 188],
#           [182, 181, 186],
#           [185, 184, 189],
#           ...,
#           [128, 136, 157],
#           [124, 130, 152],
#           [125, 131, 153]],
#
#          [[183, 182, 187],
#           [180, 179, 184],
#           [183, 182, 187],
#           ...,
#           [135, 142, 160],
#           [137, 142, 161],
#           [140, 145, 164]],
#
#          [[182, 181, 187],
#           [176, 175, 181],
#           [173, 173, 181],
#           ...,
#           [155, 161, 177],
#           [158, 164, 180],
#           [158, 164, 178]]], dtype=uint8), array([[[ 39,  71, 132],
#           [ 40,  70, 130],
#           [ 41,  72, 127],
#           ...,
#           [ 48,  75, 130],
#           [ 32,  75, 128],
#           [ 43,  72, 130]],
#
#          [[ 32,  75, 126],
#           [ 40,  71, 128],
#           [ 40,  70, 130],
#           ...,
#           [ 37,  79, 129],
#           [ 37,  81, 130],
#           [ 43,  73, 125]],
#
#          [[ 48,  73, 127],
#           [ 45,  76, 131],
#           [ 36,  75, 132],
#           ...,
#           [ 43,  74, 131],
#           [ 39,  72, 126],
#           [ 46,  76, 130]],
#
#          ...,
#
#          [[ 47,  66, 106],
#           [ 47,  67, 104],
#           [ 49,  67, 105],
#           ...,
#           [ 36,  57,  88],
#           [ 35,  55,  88],
#           [ 37,  56,  86]],
#
#          [[ 40,  65, 106],
#           [ 48,  70, 109],
#           [ 50,  65, 106],
#           ...,
#           [ 34,  54,  91],
#           [ 36,  55,  88],
#           [ 39,  57,  93]],
#
#          [[ 48,  70, 111],
#           [ 47,  65, 111],
#           [ 51,  68, 114],
#           ...,
#           [ 35,  50,  89],
#           [ 37,  52,  81],
#           [ 38,  53,  84]]], dtype=uint8), array([[[226, 240, 243],
#           [226, 240, 243],
#           [226, 240, 243],
#           ...,
#           [215, 229, 230],
#           [214, 228, 229],
#           [213, 227, 228]],
#
#          [[226, 240, 243],
#           [226, 240, 243],
#           [226, 240, 243],
#           ...,
#           [214, 228, 231],
#           [213, 227, 230],
#           [212, 226, 229]],
#
#          [[226, 240, 243],
#           [226, 240, 243],
#           [226, 240, 243],
#           ...,
#           [212, 226, 229],
#           [212, 226, 229],
#           [211, 225, 228]],
#
#          ...,
#
#          [[ 70,  96,  49],
#           [ 68,  85,  43],
#           [ 34,  41,   7],
#           ...,
#           [  5,   5,   5],
#           [  7,   7,   7],
#           [  4,   4,   4]],
#
#          [[ 50,  83,  36],
#           [ 18,  47,   3],
#           [ 39,  65,  26],
#           ...,
#           [  5,   5,   5],
#           [  6,   6,   6],
#           [  4,   4,   4]],
#
#          [[ 48,  61,  17],
#           [ 47,  62,  21],
#           [ 45,  63,  25],
#           ...,
#           [  4,   4,   4],
#           [  6,   6,   6],
#           [  4,   4,   4]]], dtype=uint8), array([[[253, 253, 253],
#           [252, 252, 252],
#           [252, 252, 252],
#           ...,
#           [194, 189, 183],
#           [194, 189, 185],
#           [197, 192, 188]],
#
#          [[253, 253, 253],
#           [252, 252, 252],
#           [252, 252, 252],
#           ...,
#           [193, 188, 182],
#           [194, 189, 185],
#           [197, 192, 188]],
#
#          [[253, 253, 253],
#           [252, 252, 252],
#           [252, 252, 252],
#           ...,
#           [192, 187, 181],
#           [193, 188, 182],
#           [197, 192, 186]],
#
#          ...,
#
#          [[ 86,  58,  44],
#           [ 87,  57,  47],
#           [ 85,  52,  47],
#           ...,
#           [  1,   5,   8],
#           [  7,  11,  14],
#           [ 26,  30,  33]],
#
#          [[ 79,  53,  40],
#           [ 86,  56,  46],
#           [ 80,  50,  42],
#           ...,
#           [  0,   3,   4],
#           [  5,  11,  11],
#           [ 23,  29,  29]],
#
#          [[ 82,  54,  42],
#           [ 94,  61,  52],
#           [ 90,  53,  47],
#           ...,
#           [  0,   3,   1],
#           [  5,  11,   9],
#           [ 19,  28,  25]]], dtype=uint8), array([[[ 24,  22,  25],
#           [ 18,  18,  20],
#           [ 19,  21,  18],
#           ...,
#           [ 38,  41,  24],
#           [ 36,  40,  23],
#           [ 39,  42,  25]],
#
#          [[ 14,  14,  14],
#           [ 23,  23,  23],
#           [ 21,  21,  19],
#           ...,
#           [ 42,  39,  24],
#           [ 38,  35,  20],
#           [ 42,  34,  21]],
#
#          [[ 21,  22,  17],
#           [ 30,  29,  25],
#           [ 28,  24,  21],
#           ...,
#           [ 55,  48,  32],
#           [ 54,  45,  30],
#           [ 46,  34,  20]],
#
#          ...,
#
#          [[103,  97,  73],
#           [112, 101,  83],
#           [108, 104,  79],
#           ...,
#           [ 70,  64,  28],
#           [ 64,  63,  32],
#           [ 60,  63,  46]],
#
#          [[108, 101,  75],
#           [101,  88,  71],
#           [118, 112,  86],
#           ...,
#           [ 69,  63,  27],
#           [ 61,  60,  30],
#           [ 56,  59,  42]],
#
#          [[ 92,  82,  57],
#           [ 98,  83,  64],
#           [109, 104,  74],
#           ...,
#           [ 73,  69,  32],
#           [ 61,  62,  31],
#           [ 57,  60,  43]]], dtype=uint8), array([[[ 20,  13,   7],
#           [ 21,  14,   8],
#           [ 24,  17,   9],
#           ...,
#           [ 33,   3,   3],
#           [ 34,   5,   1],
#           [ 37,  10,   3]],
#
#          [[ 19,  12,   6],
#           [ 18,  11,   5],
#           [ 18,  11,   3],
#           ...,
#           [ 29,   3,   2],
#           [ 29,   6,   0],
#           [ 30,  10,   3]],
#
#          [[ 18,   9,   4],
#           [ 19,  10,   5],
#           [ 15,   6,   1],
#           ...,
#           [ 25,   6,   2],
#           [ 25,   8,   1],
#           [ 26,  12,   3]],
#
#          ...,
#
#          [[172, 183, 167],
#           [174, 185, 169],
#           [173, 184, 168],
#           ...,
#           [186,  62,  90],
#           [179,  46,  75],
#           [182,  41,  76]],
#
#          [[174, 185, 169],
#           [171, 182, 166],
#           [176, 187, 171],
#           ...,
#           [183,  49,  82],
#           [185,  44,  78],
#           [190,  41,  81]],
#
#          [[173, 184, 168],
#           [171, 182, 166],
#           [176, 187, 171],
#           ...,
#           [181,  41,  76],
#           [189,  41,  77],
#           [199,  44,  84]]], dtype=uint8), array([[[253, 242, 212],
#           [253, 242, 212],
#           [253, 242, 212],
#           ...,
#           [252, 243, 212],
#           [252, 243, 212],
#           [252, 243, 212]],
#
#          [[253, 242, 212],
#           [253, 242, 212],
#           [253, 242, 212],
#           ...,
#           [252, 243, 212],
#           [252, 243, 212],
#           [252, 243, 212]],
#
#          [[253, 242, 212],
#           [253, 242, 212],
#           [253, 242, 212],
#           ...,
#           [252, 243, 212],
#           [252, 243, 212],
#           [252, 243, 212]],
#
#          ...,
#
#          [[252, 243, 212],
#           [252, 243, 212],
#           [252, 243, 212],
#           ...,
#           [252, 243, 212],
#           [252, 243, 212],
#           [252, 243, 212]],
#
#          [[252, 243, 212],
#           [252, 243, 212],
#           [252, 243, 212],
#           ...,
#           [252, 243, 212],
#           [252, 243, 212],
#           [252, 243, 212]],
#
#          [[252, 243, 212],
#           [252, 243, 212],
#           [252, 243, 212],
#           ...,
#           [252, 243, 212],
#           [252, 243, 212],
#           [252, 243, 212]]], dtype=uint8), array([[[ 52,  53,  57],
#           [ 46,  47,  51],
#           [ 47,  48,  52],
#           ...,
#           [ 22,  22,  32],
#           [ 24,  24,  34],
#           [ 28,  26,  37]],
#
#          [[ 48,  49,  53],
#           [ 48,  49,  53],
#           [ 52,  53,  57],
#           ...,
#           [ 27,  27,  37],
#           [ 28,  28,  38],
#           [ 29,  29,  37]],
#
#          [[ 51,  52,  56],
#           [ 35,  36,  40],
#           [ 49,  50,  54],
#           ...,
#           [ 26,  28,  41],
#           [ 27,  27,  39],
#           [ 25,  25,  37]],
#
#          ...,
#
#          [[ 87, 121, 130],
#           [ 96, 130, 139],
#           [ 98, 132, 141],
#           ...,
#           [125, 163, 172],
#           [128, 165, 174],
#           [125, 162, 171]],
#
#          [[ 92, 126, 135],
#           [ 94, 128, 137],
#           [ 87, 121, 130],
#           ...,
#           [110, 140, 150],
#           [ 93, 122, 130],
#           [ 72,  99, 108]],
#
#          [[ 89, 123, 132],
#           [ 95, 129, 138],
#           [ 96, 130, 139],
#           ...,
#           [ 47,  71,  81],
#           [ 35,  58,  66],
#           [ 52,  71,  78]]], dtype=uint8), array([[[  4,  16,  42],
#           [  4,  16,  42],
#           [  5,  17,  41],
#           ...,
#           [  2,   7,  37],
#           [  3,   8,  38],
#           [  6,  11,  41]],
#
#          [[  2,  12,  39],
#           [  3,  13,  40],
#           [  4,  16,  42],
#           ...,
#           [  2,   7,  37],
#           [  3,   8,  38],
#           [  6,  11,  41]],
#
#          [[  3,  10,  38],
#           [  3,  10,  38],
#           [  5,  12,  40],
#           ...,
#           [  2,   7,  37],
#           [  3,   8,  38],
#           [  6,  11,  41]],
#
#          ...,
#
#          [[250, 216, 152],
#           [135, 151,  88],
#           [209, 197, 121],
#           ...,
#           [ 38,  72,  82],
#           [ 37,  71,  81],
#           [ 38,  70,  81]],
#
#          [[191, 175, 113],
#           [212, 184, 121],
#           [156, 160, 101],
#           ...,
#           [ 37,  74,  82],
#           [ 40,  74,  84],
#           [ 39,  71,  82]],
#
#          [[234, 217, 137],
#           [175, 156,  97],
#           [237, 202, 164],
#           ...,
#           [ 30,  67,  73],
#           [ 36,  70,  79],
#           [ 37,  67,  78]]], dtype=uint8), array([[[255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255],
#           ...,
#           [255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255]],
#
#          [[255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255],
#           ...,
#           [255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255]],
#
#          [[255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255],
#           ...,
#           [255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255]],
#
#          ...,
#
#          [[140, 143,  56],
#           [107, 107,  17],
# ...
#           [ 37,  74,  82],
#           [ 40,  74,  84],
#           [ 39,  71,  82]],
#
#          [[234, 217, 137],
#           [175, 156,  97],
#           [237, 202, 164],
#           ...,
#           [ 30,  67,  73],
#           [ 36,  70,  79],
#           [ 37,  67,  78]]], dtype=uint8), array([[[255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255],
#           ...,
#           [255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255]],
#
#          [[255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255],
#           ...,
#           [255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255]],
#
#          [[255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255],
#           ...,
#           [255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255]],
#
#          ...,
#
#          [[140, 143,  56],
#           [107, 107,  17],
#           [124, 124,  34],
#           ...,
#           [127, 122,  38],
#           [ 58,  51,   5],
#           [110, 112,  13]],
#
#          [[101,  98,  29],
#           [149, 151,  68],
#           [141, 144,  55],
#           ...,
#           [183, 183,  83],
#           [112, 111,  28],
#           [125, 127,  26]],
#
#          [[ 68,  68,   6],
#           [109, 115,  27],
#           [ 98, 105,  10],
#           ...,
#           [155, 152,  59],
#           [134, 134,  36],
#           [110, 110,  12]]], dtype=uint8), array([[[202, 202, 202],
#           [202, 202, 202],
#           [202, 202, 202],
#           ...,
#           [184, 184, 184],
#           [190, 190, 190],
#           [171, 171, 171]],
#
#          [[202, 202, 202],
#           [202, 202, 202],
#           [202, 202, 202],
#           ...,
#           [184, 184, 184],
#           [189, 189, 189],
#           [177, 177, 177]],
#
#          [[202, 202, 202],
#           [202, 202, 202],
#           [202, 202, 202],
#           ...,
#           [184, 184, 184],
#           [188, 188, 188],
#           [180, 180, 180]],
#
#          ...,
#
#          [[ 53,  53,  53],
#           [ 41,  41,  41],
#           [ 39,  39,  39],
#           ...,
#           [ 24,  24,  24],
#           [ 26,  26,  26],
#           [ 24,  24,  24]],
#
#          [[ 73,  73,  73],
#           [ 60,  60,  60],
#           [ 60,  60,  60],
#           ...,
#           [ 20,  20,  20],
#           [ 23,  23,  23],
#           [ 23,  23,  23]],
#
#          [[ 84,  84,  84],
#           [ 75,  75,  75],
#           [ 79,  79,  79],
#           ...,
#           [ 19,  19,  19],
#           [ 19,  19,  19],
#           [ 21,  21,  21]]], dtype=uint8), array([[[ 81, 149, 198],
#           [ 84, 147, 198],
#           [ 82, 150, 197],
#           ...,
#           [ 28, 101, 229],
#           [ 24,  97, 225],
#           [ 29, 100, 228]],
#
#          [[ 78, 150, 198],
#           [ 77, 151, 198],
#           [ 83, 149, 197],
#           ...,
#           [ 31, 105, 228],
#           [ 26, 102, 224],
#           [ 28, 104, 226]],
#
#          [[ 82, 150, 199],
#           [ 79, 151, 199],
#           [ 80, 150, 199],
#           ...,
#           [ 30,  99, 228],
#           [ 30,  99, 228],
#           [ 30,  99, 226]],
#
#          ...,
#
#          [[ 51, 195, 230],
#           [ 61, 213, 226],
#           [ 63, 203, 226],
#           ...,
#           [147, 193, 216],
#           [146, 194, 216],
#           [144, 195, 216]],
#
#          [[ 62, 196, 233],
#           [ 47, 226, 223],
#           [ 76, 215, 234],
#           ...,
#           [145, 193, 215],
#           [145, 193, 215],
#           [146, 194, 216]],
#
#          [[ 57, 206, 230],
#           [ 59, 210, 231],
#           [ 60, 213, 231],
#           ...,
#           [146, 194, 216],
#           [147, 193, 216],
#           [147, 193, 216]]], dtype=uint8), array([[[237, 241, 242],
#           [237, 241, 242],
#           [238, 242, 243],
#           ...,
#           [237, 237, 237],
#           [237, 237, 237],
#           [238, 238, 238]],
#
#          [[238, 242, 243],
#           [238, 242, 243],
#           [238, 242, 243],
#           ...,
#           [236, 236, 236],
#           [237, 237, 237],
#           [237, 237, 237]],
#
#          [[239, 243, 244],
#           [238, 242, 243],
#           [237, 241, 242],
#           ...,
#           [236, 236, 236],
#           [236, 236, 236],
#           [237, 237, 237]],
#
#          ...,
#
#          [[128, 128, 128],
#           [125, 124, 120],
#           [130, 134, 117],
#           ...,
#           [116, 109,  90],
#           [127, 120, 102],
#           [122, 116, 102]],
#
#          [[104, 104,  92],
#           [ 95,  91,  92],
#           [118, 119, 101],
#           ...,
#           [108,  91,  71],
#           [ 97,  85,  69],
#           [106,  99,  91]],
#
#          [[115, 115,  91],
#           [127, 127, 115],
#           [149, 150, 136],
#           ...,
#           [ 90,  79,  73],
#           [ 78,  69,  64],
#           [ 76,  67,  62]]], dtype=uint8), array([[[12, 20, 23],
#           [12, 20, 23],
#           [11, 19, 21],
#           ...,
#           [64, 72, 75],
#           [63, 73, 75],
#           [63, 73, 75]],
#
#          [[17, 26, 33],
#           [16, 25, 30],
#           [15, 22, 28],
#           ...,
#           [63, 71, 74],
#           [64, 72, 75],
#           [65, 75, 77]],
#
#          [[19, 28, 37],
#           [19, 28, 37],
#           [18, 27, 36],
#           ...,
#           [63, 70, 76],
#           [64, 71, 77],
#           [65, 72, 78]],
#
#          ...,
#
#          [[64, 48, 33],
#           [63, 47, 32],
#           [62, 46, 31],
#           ...,
#           [56, 47, 32],
#           [54, 45, 30],
#           [52, 45, 29]],
#
#          [[65, 52, 36],
#           [64, 51, 35],
#           [64, 51, 35],
#           ...,
#           [58, 46, 32],
#           [56, 47, 32],
#           [56, 49, 33]],
#
#          [[64, 51, 35],
#           [64, 51, 35],
#           [65, 52, 36],
#           ...,
#           [58, 46, 32],
#           [58, 49, 34],
#           [59, 52, 36]]], dtype=uint8), array([[[225, 232, 238],
#           [226, 233, 239],
#           [226, 233, 239],
#           ...,
#           [221, 225, 228],
#           [219, 224, 228],
#           [220, 225, 229]],
#
#          [[223, 230, 236],
#           [224, 231, 237],
#           [224, 231, 237],
#           ...,
#           [230, 231, 233],
#           [227, 231, 232],
#           [227, 231, 234]],
#
#          [[225, 232, 238],
#           [225, 232, 238],
#           [225, 232, 238],
#           ...,
#           [233, 235, 234],
#           [234, 234, 234],
#           [233, 233, 233]],
#
#          ...,
#
#          [[ 13,  17,  28],
#           [ 17,  24,  34],
#           [ 20,  29,  38],
#           ...,
#           [ 28,  27,  32],
#           [ 25,  25,  27],
#           [ 33,  33,  33]],
#
#          [[ 22,  29,  39],
#           [ 28,  35,  45],
#           [ 32,  39,  49],
#           ...,
#           [ 31,  31,  33],
#           [ 28,  28,  28],
#           [ 27,  27,  27]],
#
#          [[ 23,  30,  40],
#           [ 27,  34,  44],
#           [ 22,  26,  37],
#           ...,
#           [ 31,  31,  33],
#           [ 28,  28,  28],
#           [ 26,  26,  26]]], dtype=uint8), array([[[105, 117,  71],
#           [118, 129,  86],
#           [109, 120,  78],
#           ...,
#           [ 79,  73,  25],
#           [ 71,  63,  26],
#           [ 99,  90,  61]],
#
#          [[101, 107,  71],
#           [126, 132,  98],
#           [120, 126,  92],
#           ...,
#           [ 91,  84,  38],
#           [ 66,  58,  22],
#           [ 91,  82,  53]],
#
#          [[103,  99,  70],
#           [117, 113,  84],
#           [138, 135, 104],
#           ...,
#           [101,  94,  52],
#           [ 92,  84,  48],
#           [102,  93,  64]],
#
#          ...,
#
#          [[132, 119, 100],
#           [141, 128, 109],
#           [113, 100,  81],
#           ...,
#           [150, 134, 118],
#           [138, 122, 106],
#           [149, 133, 117]],
#
#          [[123, 112,  92],
#           [133, 122, 102],
#           [129, 118,  98],
#           ...,
#           [146, 130, 114],
#           [148, 132, 116],
#           [141, 125, 109]],
#
#          [[133, 121, 105],
#           [138, 126, 110],
#           [149, 137, 121],
#           ...,
#           [138, 122, 106],
#           [157, 141, 125],
#           [134, 118, 102]]], dtype=uint8), array([[[60, 46, 46],
#           [76, 62, 61],
#           [81, 62, 58],
#           ...,
#           [11,  3,  0],
#           [50, 47, 42],
#           [74, 64, 62]],
#
#          [[46, 30, 31],
#           [71, 55, 55],
#           [83, 63, 62],
#           ...,
#           [ 9,  1,  0],
#           [18, 14, 11],
#           [65, 62, 57]],
#
#          [[86, 67, 69],
#           [84, 66, 66],
#           [91, 71, 70],
#           ...,
#           [ 9,  4,  1],
#           [ 4,  0,  0],
#           [35, 30, 27]],
#
#          ...,
#
#          [[94, 99, 95],
#           [94, 99, 95],
#           [86, 91, 87],
#           ...,
#           [17, 35, 45],
#           [15, 33, 45],
#           [19, 36, 46]],
#
#          [[92, 97, 93],
#           [92, 97, 93],
#           [93, 98, 94],
#           ...,
#           [16, 34, 44],
#           [18, 36, 48],
#           [17, 35, 47]],
#
#          [[94, 99, 95],
#           [93, 98, 94],
#           [91, 96, 92],
#           ...,
#           [15, 33, 43],
#           [17, 35, 47],
#           [18, 36, 48]]], dtype=uint8)]),
#   'yolo': FramesofInterest(ltl_formula='P>=0.80 ["vase" U "boat"]', foi_list=[[17], [24, 28], [32, 41, 47]], frame_images=[array([[[ 85, 131, 193],
#           [ 86, 132, 194],
#           [ 86, 132, 192],
#           ...,
#           [ 74, 115, 181],
#           [ 74, 115, 179],
#           [ 75, 116, 180]],
#
#          [[ 87, 135, 199],
#           [ 87, 135, 199],
#           [ 89, 134, 199],
#           ...,
#           [ 77, 118, 182],
#           [ 78, 119, 181],
#           [ 78, 120, 180]],
#
#          [[ 86, 135, 202],
#           [ 87, 134, 202],
#           [ 87, 135, 201],
#           ...,
#           [ 78, 120, 180],
#           [ 78, 120, 180],
#           [ 78, 120, 178]],
#
#          ...,
#
#          [[164, 170, 170],
#           [171, 177, 177],
#           [178, 182, 183],
#           ...,
#           [ 90, 108, 110],
#           [ 86, 101, 104],
#           [ 72,  87,  94]],
#
#          [[170, 179, 178],
#           [174, 183, 182],
#           [179, 185, 185],
#           ...,
#           [ 73,  91,  93],
#           [ 82, 100, 102],
#           [101, 116, 121]],
#
#          [[175, 185, 184],
#           [176, 185, 184],
#           [176, 182, 182],
#           ...,
#           [ 58,  79,  82],
#           [ 93, 112, 116],
#           [104, 121, 128]]], dtype=uint8), array([[[130, 163,  76],
#           [124, 164,  76],
#           [119, 158,  79],
#           ...,
#           [ 75,  78,  49],
#           [ 82,  78,  53],
#           [ 83,  79,  70]],
#
#          [[120, 149,  65],
#           [128, 153,  59],
#           [120, 149,  57],
#           ...,
#           [ 83,  81,  42],
#           [ 86,  84,  46],
#           [ 71,  83,  61]],
#
#          [[113, 146,  57],
#           [118, 143,  49],
#           [118, 146,  46],
#           ...,
#           [ 69,  84,  55],
#           [ 83,  82,  61],
#           [ 90,  78,  54]],
#
#          ...,
#
#          [[138, 140, 126],
#           [141, 145, 120],
#           [139, 141, 119],
#           ...,
#           [ 91, 100,  73],
#           [ 86, 100,  77],
#           [108, 103,  84]],
#
#          [[138, 141, 120],
#           [144, 138, 122],
#           [145, 141, 112],
#           ...,
#           [ 96,  87,  70],
#           [ 87,  89,  65],
#           [ 92,  96,  69]],
#
#          [[143, 136, 117],
#           [142, 136, 120],
#           [139, 139, 101],
#           ...,
#           [ 93,  88,  84],
#           [ 97,  89,  76],
#           [ 86,  89,  70]]], dtype=uint8), array([[[200, 203, 194],
#           [200, 203, 194],
#           [200, 203, 194],
#           ...,
#           [211, 222, 218],
#           [211, 222, 218],
#           [211, 222, 218]],
#
#          [[200, 203, 194],
#           [200, 203, 194],
#           [201, 204, 195],
#           ...,
#           [210, 221, 217],
#           [210, 221, 217],
#           [210, 221, 217]],
#
#          [[200, 203, 194],
#           [200, 203, 194],
#           [201, 204, 195],
#           ...,
#           [210, 221, 217],
#           [210, 221, 217],
#           [210, 221, 217]],
#
#          ...,
#
#          [[102,  97,  78],
#           [ 98,  93,  74],
#           [101,  96,  77],
#           ...,
#           [ 99, 100,  84],
#           [ 99, 100,  84],
#           [ 99, 100,  84]],
#
#          [[101,  96,  77],
#           [ 98,  93,  74],
#           [101,  96,  77],
#           ...,
#           [ 99, 100,  84],
#           [ 99, 100,  84],
#           [ 99, 100,  84]],
#
#          [[101,  96,  77],
#           [ 98,  93,  74],
#           [101,  96,  77],
#           ...,
#           [ 99, 100,  84],
#           [ 99, 100,  84],
#           [ 99, 100,  84]]], dtype=uint8), array([[[101,  88,  71],
#           [102,  89,  72],
#           [101,  88,  71],
#           ...,
#           [132,  98,  26],
#           [129,  95,  23],
#           [127,  93,  21]],
#
#          [[102,  88,  75],
#           [102,  88,  75],
#           [102,  88,  75],
#           ...,
#           [130,  96,  24],
#           [129,  95,  23],
#           [127,  93,  21]],
#
#          [[102,  88,  79],
#           [102,  88,  77],
#           [103,  89,  78],
#           ...,
#           [130,  96,  24],
#           [128,  94,  22],
#           [125,  91,  19]],
#
#          ...,
#
#          [[ 82,  75,  69],
#           [ 87,  80,  72],
#           [ 88,  81,  73],
#           ...,
#           [252, 252, 252],
#           [142, 142, 142],
#           [  0,   0,   0]],
#
#          [[ 84,  77,  71],
#           [ 85,  78,  72],
#           [ 87,  80,  74],
#           ...,
#           [165, 165, 165],
#           [ 78,  78,  78],
#           [  1,   1,   1]],
#
#          [[ 84,  77,  71],
#           [ 90,  83,  77],
#           [ 86,  79,  73],
#           ...,
#           [  0,   0,   0],
#           [  1,   1,   1],
#           [  7,   7,   7]]], dtype=uint8), array([[[  4,  16,  42],
#           [  4,  16,  42],
#           [  5,  17,  41],
#           ...,
#           [  2,   7,  37],
#           [  3,   8,  38],
#           [  6,  11,  41]],
#
#          [[  2,  12,  39],
#           [  3,  13,  40],
#           [  4,  16,  42],
#           ...,
#           [  2,   7,  37],
#           [  3,   8,  38],
#           [  6,  11,  41]],
#
#          [[  3,  10,  38],
#           [  3,  10,  38],
#           [  5,  12,  40],
#           ...,
#           [  2,   7,  37],
#           [  3,   8,  38],
#           [  6,  11,  41]],
#
#          ...,
#
#          [[250, 216, 152],
#           [135, 151,  88],
#           [209, 197, 121],
#           ...,
#           [ 38,  72,  82],
#           [ 37,  71,  81],
#           [ 38,  70,  81]],
#
#          [[191, 175, 113],
#           [212, 184, 121],
#           [156, 160, 101],
#           ...,
#           [ 37,  74,  82],
#           [ 40,  74,  84],
#           [ 39,  71,  82]],
#
#          [[234, 217, 137],
#           [175, 156,  97],
#           [237, 202, 164],
#           ...,
#           [ 30,  67,  73],
#           [ 36,  70,  79],
#           [ 37,  67,  78]]], dtype=uint8), array([[[225, 232, 238],
#           [226, 233, 239],
#           [226, 233, 239],
#           ...,
#           [221, 225, 228],
#           [219, 224, 228],
#           [220, 225, 229]],
#
#          [[223, 230, 236],
#           [224, 231, 237],
#           [224, 231, 237],
#           ...,
#           [230, 231, 233],
#           [227, 231, 232],
#           [227, 231, 234]],
#
#          [[225, 232, 238],
#           [225, 232, 238],
#           [225, 232, 238],
#           ...,
#           [233, 235, 234],
#           [234, 234, 234],
#           [233, 233, 233]],
#
#          ...,
#
#          [[ 13,  17,  28],
#           [ 17,  24,  34],
#           [ 20,  29,  38],
#           ...,
#           [ 28,  27,  32],
#           [ 25,  25,  27],
#           [ 33,  33,  33]],
#
#          [[ 22,  29,  39],
#           [ 28,  35,  45],
#           [ 32,  39,  49],
#           ...,
#           [ 31,  31,  33],
#           [ 28,  28,  28],
#           [ 27,  27,  27]],
#
#          [[ 23,  30,  40],
#           [ 27,  34,  44],
#           [ 22,  26,  37],
#           ...,
#           [ 31,  31,  33],
#           [ 28,  28,  28],
#           [ 26,  26,  26]]], dtype=uint8)], annotated_images=[], frame_idx_to_real_idx={17: None, 24: None, 28: None, 32: None, 41: None, 47: None}),
#   'yolo_classification_metrics': {'accuracy': 0.6,
#    'precision': 1.0,
#    'recall': 0.6,
#    'f1': 0.7499999999999999}}}

# %%
import numpy as np 
x = np.array(range(30))/50 + 0.2
x
# Out:
# array([0.2 , 0.22, 0.24, 0.26, 0.28, 0.3 , 0.32, 0.34, 0.36, 0.38, 0.4 ,
#        0.42, 0.44, 0.46, 0.48, 0.5 , 0.52, 0.54, 0.56, 0.58, 0.6 , 0.62,
#        0.64, 0.66, 0.68, 0.7 , 0.72, 0.74, 0.76, 0.78])

# %%
np.array(range(30))/50
# Out:
# array([0.  , 0.02, 0.04, 0.06, 0.08, 0.1 , 0.12, 0.14, 0.16, 0.18, 0.2 ,
#        0.22, 0.24, 0.26, 0.28, 0.3 , 0.32, 0.34, 0.36, 0.38, 0.4 , 0.42,
#        0.44, 0.46, 0.48, 0.5 , 0.52, 0.54, 0.56, 0.58])
